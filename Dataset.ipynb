# %% [markdown]
# <a href="https://colab.research.google.com/github/SHEU6000/TECH-BRO/blob/master/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('STEG_BILLING_HISTORY.csv')

# %%
client_0_bills = df.head(10)
client_0_bills
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0    3/24/2014          11       1335667.0               0
# 1  train_Client_0    3/29/2013          11       1335667.0               0
# 2  train_Client_0    3/23/2015          11       1335667.0               0
# 3  train_Client_0    7/13/2015          11       1335667.0               0
# 4  train_Client_0   11/17/2016          11       1335667.0               0
# 5  train_Client_0    7/17/2017          11       1335667.0               0
# 6  train_Client_0    12/7/2018          11       1335667.0               0
# 7  train_Client_0    3/19/2019          11       1335667.0               0
# 8  train_Client_0    7/22/2011          11       1335667.0               0
# 9  train_Client_0   11/22/2011          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 16 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   client_id             1048575 non-null  object
#  1   invoice_date          1048575 non-null  object
#  2   tarif_type            1048575 non-null  int64
#  3   counter_number        1048564 non-null  float64
#  4   counter_statue        1048575 non-null  int64
#  5   counter_code          1048575 non-null  int64
#  6   reading_remarque      1047503 non-null  float64
#  7   counter_coefficient   1048575 non-null  int64
#  8   consommation_level_1  1048575 non-null  int64
#  9   consommation_level_2  1048575 non-null  int64
#  10  consommation_level_3  1048575 non-null  int64
#  11  consommation_level_4  1048575 non-null  int64
#  12  old_index             1048575 non-null  int64
#  13  new_index             1048575 non-null  int64
# ...

# %%
df.shape
# Out:
# (1048575, 16)

# %%
rows, columns = df.shape
print(f'Rows: {rows}, Columns: {columns}')
# Out:
# Rows: 1048575, Columns: 16

# %%
categorical_features = df.select_dtypes(include=['object']).columns

# %%
print(f"Number of Categorical_features: {len(categorical_features)}")
print(f"\nCategorical_features: {list(categorical_features)}")
# Out:
# Number of Categorical_features: 3
#
# Categorical_features: ['client_id', 'invoice_date', 'counter_type']

# %%
print(df.isnull().sum())
# Out:
# client_id                0
# invoice_date             0
# tarif_type               0
# counter_number          11
# counter_statue           0
# counter_code             0
# reading_remarque         0
# counter_coefficient      0
# consommation_level_1     0
# consommation_level_2     0
# consommation_level_3     0
# consommation_level_4     0
# old_index                0
# new_index                0
# months_number            0
# counter_type             0
# dtype: int64

# %%
df
# Out:
#                    client_id invoice_date  tarif_type  counter_number  \
# 0             train_Client_0    3/24/2014          11       1335667.0
# 1             train_Client_0    3/29/2013          11       1335667.0
# 2             train_Client_0    3/23/2015          11       1335667.0
# 3             train_Client_0    7/13/2015          11       1335667.0
# 4             train_Client_0   11/17/2016          11       1335667.0
# ...                      ...          ...         ...             ...
# 1048570  train_Client_128439    6/26/2007          40         42475.0
# 1048571  train_Client_128439   10/24/2007          11        464740.0
# 1048572  train_Client_128439     5/6/2015          40         42475.0
# 1048573  train_Client_128439     5/6/2015          11        464740.0
# 1048574  train_Client_128439   10/24/2007          40         42475.0
#
#          counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
df['reading_remarque'].fillna(df['reading_remarque'].mean(), inplace=True)
# Out:
# <ipython-input-55-8f3815b3c93a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reading_remarque'].fillna(df['reading_remarque'].mean(), inplace=True)

# %%
df
# Out:
#                    client_id invoice_date  tarif_type  counter_number  \
# 0             train_Client_0    3/24/2014          11       1335667.0
# 1             train_Client_0    3/29/2013          11       1335667.0
# 2             train_Client_0    3/23/2015          11       1335667.0
# 3             train_Client_0    7/13/2015          11       1335667.0
# 4             train_Client_0   11/17/2016          11       1335667.0
# ...                      ...          ...         ...             ...
# 1048570  train_Client_128439    6/26/2007          40         42475.0
# 1048571  train_Client_128439   10/24/2007          11        464740.0
# 1048572  train_Client_128439     5/6/2015          40         42475.0
# 1048573  train_Client_128439     5/6/2015          11        464740.0
# 1048574  train_Client_128439   10/24/2007          40         42475.0
#
#          counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
numeric_features = df.describe()
print(numeric_features)
# Out:
#          tarif_type  counter_number  counter_statue  counter_code  \
# count  1.048575e+06    1.048564e+06    1.048575e+06  1.048575e+06
# mean   2.013626e+01    1.209212e+11    4.203419e-02  1.722212e+02
# std    1.348246e+01    1.646711e+12    3.745414e-01  1.335823e+02
# min    8.000000e+00    0.000000e+00    0.000000e+00  5.000000e+00
# 25%    1.100000e+01    1.214730e+05    0.000000e+00  5.000000e+00
# 50%    1.100000e+01    4.904750e+05    0.000000e+00  2.030000e+02
# 75%    4.000000e+01    1.112725e+06    0.000000e+00  2.070000e+02
# max    4.500000e+01    2.738110e+13    5.000000e+00  6.000000e+02
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count      1.048575e+06         1.048575e+06          1.048575e+06
# mean       7.315289e+00         1.000236e+00          4.097446e+02
# std        1.358930e+00         8.306498e-02          5.882746e+02
# min        6.000000e+00         0.000000e+00          0.000000e+00
# ...

# %%
df
# Out:
#                    client_id invoice_date  tarif_type  counter_number  \
# 0             train_Client_0    3/24/2014          11       1335667.0
# 1             train_Client_0    3/29/2013          11       1335667.0
# 2             train_Client_0    3/23/2015          11       1335667.0
# 3             train_Client_0    7/13/2015          11       1335667.0
# 4             train_Client_0   11/17/2016          11       1335667.0
# ...                      ...          ...         ...             ...
# 1048570  train_Client_128439    6/26/2007          40         42475.0
# 1048571  train_Client_128439   10/24/2007          11        464740.0
# 1048572  train_Client_128439     5/6/2015          40         42475.0
# 1048573  train_Client_128439     5/6/2015          11        464740.0
# 1048574  train_Client_128439   10/24/2007          40         42475.0
#
#          counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
descriptive_statistics = numeric_features.describe()
descriptive_statistics
# Out:
#          tarif_type  counter_number  counter_statue  counter_code  \
# count  8.000000e+00    8.000000e+00    8.000000e+00  8.000000e+00
# mean   1.310905e+05    3.643592e+12    1.310726e+05  1.312376e+05
# std    3.707197e+05    9.608366e+12    3.707270e+05  3.706603e+05
# min    8.000000e+00    0.000000e+00    0.000000e+00  5.000000e+00
# 25%    1.100000e+01    3.982245e+05    0.000000e+00  1.014367e+02
# 50%    1.680936e+01    1.080644e+06    2.101709e-02  1.876106e+02
# 75%    4.125000e+01    5.023687e+11    1.530906e+00  3.052500e+02
# max    1.048575e+06    2.738110e+13    1.048575e+06  1.048575e+06
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count      8.000000e+00         8.000000e+00          8.000000e+00
# mean       1.310776e+05         1.310786e+05          1.436768e+05
# std        3.707249e+05         3.707245e+05          3.672573e+05
# min        1.358930e+00         0.000000e+00          0.000000e+00
# ...

# %%
client_0_records = df[df['client_id'] == 'train_Client_0']
client_0_records
# Out:
#          client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0   train_Client_0    3/24/2014          11       1335667.0           203
# 1   train_Client_0    3/29/2013          11       1335667.0           203
# 2   train_Client_0    3/23/2015          11       1335667.0           203
# 3   train_Client_0    7/13/2015          11       1335667.0           207
# 4   train_Client_0   11/17/2016          11       1335667.0           207
# 5   train_Client_0    7/17/2017          11       1335667.0           207
# 6   train_Client_0    12/7/2018          11       1335667.0           207
# 7   train_Client_0    3/19/2019          11       1335667.0           207
# 8   train_Client_0    7/22/2011          11       1335667.0           203
# 9   train_Client_0   11/22/2011          11       1335667.0           203
# 10  train_Client_0   11/25/2008          11       1335667.0           203
# 11  train_Client_0    7/23/2012          11       1335667.0           203
# ...

# %%
label_encoder = LabelEncoder()

# %%
df['counter_type_encoded'] = label_encoder.fit_transform(df['counter_type'])

# %%
print(df)
# Out:
#                    client_id invoice_date  tarif_type  counter_number  \
# 0             train_Client_0    3/24/2014          11       1335667.0
# 1             train_Client_0    3/29/2013          11       1335667.0
# 2             train_Client_0    3/23/2015          11       1335667.0
# 3             train_Client_0    7/13/2015          11       1335667.0
# 4             train_Client_0   11/17/2016          11       1335667.0
# ...                      ...          ...         ...             ...
# 1048570  train_Client_128439    6/26/2007          40         42475.0
# 1048571  train_Client_128439   10/24/2007          11        464740.0
# 1048572  train_Client_128439     5/6/2015          40         42475.0
# 1048573  train_Client_128439     5/6/2015          11        464740.0
# 1048574  train_Client_128439   10/24/2007          40         42475.0
#
#          counter_code  reading_remarque  counter_coefficient  \
# 0                 203               8.0                    1
# ...

# %%
df.drop(["counter_statue"], axis="columns", inplace=True)

# %%
df.head()
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0    3/24/2014          11       1335667.0           203
# 1  train_Client_0    3/29/2013          11       1335667.0           203
# 2  train_Client_0    3/23/2015          11       1335667.0           203
# 3  train_Client_0    7/13/2015          11       1335667.0           207
# 4  train_Client_0   11/17/2016          11       1335667.0           207
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                    1                    82
# 1               6.0                    1                  1200
# 2               8.0                    1                   123
# 3               8.0                    1                   102
# 4               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# ...
